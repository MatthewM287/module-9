# %% [markdown]
# <a href="https://colab.research.google.com/github/MatthewM287/module-9/blob/main/Module_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

def themax(numbers):
  my_max = numbers[0]
  for i in numbers:
    if my_max < i:
      my_max = i
  return my_max

def themin(numbers):
  my_min = numbers[0]
  for i in numbers:
    if my_min > i:
      my_min = i
  return my_min

def theaverage(numbers):
  total = 0
  for in numbers:
    total += i
    return total/len(numbers)



a = [8,6,2,9,13,3]
print(themax(a))
# Out:
# 13

# %%
def shape_choice():
  data = int(input("which shape would you like to find the area of? (triangle -> 1,square)"))
  if data is 1:
    base = float(input("what is the base?"))
    height = float(input("what is the height"))
    triangle(base, height)
  elif data is 2:
    side = float(input("what is the side?"))
    square()
def triangle(base, height):
  print("the area of the triangle is: ", base*height)
def square(side):
  print("the area of the square is ", side*side)
shape()

# %%
def approach(numbers):
  choice = int(input("would you like to see the list 2 times (write 1) or would you like to see the numbers double (write 2)"))
  if choice is 1:
    numbers = numbers*2
  elif choice is 2:
    numbers = np.array(numbers)
    numbers = numbers *2
  return numbers
vals = [1, 2, 3, 4, 5, 6]
print(approach(vals))

# %%
def concat_lists(list_1, list_2):
  concated = []
  for (i, j) in zip(list_1, list_2):
    concated.append(int(str(i) + str(j)))
  return concated
list_1 = [1,2,3]
list_2 = [4,5,6]
print(concat_lists(list_1,list_2))

# %%
def oddfib(k):
  first = 1
  second = 1
  total = first + second
  for i in range(k):
    third = first + second
    if (third % 2 == 1):
      total += third
    first = second
    second = third
  return total
print(oddfib(10))

# %%
def fifth_powers():
  for spot in range(2,1000000):
    digits = [int(i) for i in str(spot)]
    total = 0
    for k in digits:
      total += m.pow(k,5)
    if total == spot:
      print(total)
fifth_powers()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fc7f661673fd> in <module>()
#       7     if total == spot:
#       8       print(total)
# ----> 9 fifth_powers()
#
# <ipython-input-1-fc7f661673fd> in fifth_powers()
#       4     total = 0
#       5     for k in digits:
# ----> 6       total += m.pow(k,5)
#       7     if total == spot:
#       8       print(total)
#
# NameError: name 'm' is not defined
